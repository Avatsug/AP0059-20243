# %% [markdown]
# Gustavo A. Aparicio V. - 20232005091

# %%
import pandas as pd

# %%
data = {"name": ["Sally", "Jhon", "Kim"], "age": [4, 6 ,7], "gender": ["female", "male", "male"]} # Crea un diccionario

# %%
pd.DataFrame(data) # Al dataframe 'pd' se le añade el diccionario 'data'
# Out:
#     name  age  gender
# 0  Sally    4  female
# 1   Jhon    6    male
# 2    Kim    7    male

# %%
pd.DataFrame(data, index = ["Kid1", "Kid2", "Kid3"]) # Cambia los valores del índice
# Out:
#        name  age  gender
# Kid1  Sally    4  female
# Kid2   Jhon    6    male
# Kid3    Kim    7    male
