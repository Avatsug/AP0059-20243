# %% [markdown]
# Gustavo A. Aparicio V. - 20232006091

# %%
import pandas as pd # Importa la biblioteca 'pandas' y se le asigna un nombre 'pd' para facilidad
pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv") # Instrucción para leer un archivo CSV, usando el método 'read_csv'
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
from google.colab import drive # Importa la biblioteca 'drive' de 'google.colab', utilizada para el funcionamiento de los códigos
drive.mount('/content/drive') # Intrucción para tener acceso a los archivos del 'google drive'
# Out:
# Mounted at /content/drive

# %%
cities = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", usecols = ["City"]) # Dataframe con la instrucción para leer un archivo CSV, pero solo la columna 'city' por el agurmento 'usecols'
pop = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", usecols = ["Population"]) # Dataframe con la instrucción para leer un archivo CSV, pero solo la columna 'population' por el agurmento 'usecols'
pop.head() # Método 'head()' para mostrar en consola/pantalla las cinco (5) primeras filas
cities.tail() # Método 'tail()' para mostrar en consola/pantalla las cinco (5) últimas filas
# Out:
#         City
# 596  Lobitos
# 597   Bremen
# 598   Harare
# 599    Lagos
# 600   Oshawa

# %%
cities.head() # Método 'head()' para mostrar en consola/pantalla las cinco (5) primeras filas
# Out:
#             City
# 0         Kajuru
# 1           Leon
# 2            Osh
# 3  Shumikhinskiy
# 4       Bundoran

# %%
cities.tail() # Método 'tail()' para mostrar en consola/pantalla las cinco (5) últimas filas
# Out:
#         City
# 596  Lobitos
# 597   Bremen
# 598   Harare
# 599    Lagos
# 600   Oshawa

# %%
pop.tail(n = 8) # Método 'tail()' para mostrar en consola/pantalla un número determinado de filas 'n=8' empezando desde la última
# Out:
#      Population
# 593       16755
# 594       16325
# 595       16905
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000

# %%
cities.count() # Método 'count()' para contar las filas del archivo CSV del dataframe 'cities'
# Out:
# City    601
# dtype: int64

# %%
pop.count() # Método 'count()' para contar las filas del archivo CSV del dataframe 'pop'
# Out:
# Population    601
# dtype: int64

# %%
cities.describe() # Método 'describe()' muestra un resumen estadístico del dataframe 'cities'
# Out:
#                City
# count           601
# unique          578
# top     San Antonio
# freq              4

# %%
pop.describe() # Método 'describe()' muestra un resumen estadístico del dataframe 'pop'
# Out:
#          Population
# count    601.000000
# mean   13932.415973
# std     6765.873291
# min     2528.000000
# 25%     7801.000000
# 50%    13966.000000
# 75%    19752.000000
# max    38745.000000

# %%
# cities.sort_values()
cities.sort_values(by = ["City"], ascending = False) # Método 'sort_values()' organiza los datos del dataframe 'cities' de acuerdo a la columna 'city', alfabéticamente desde la Z hasta al A por el argumento 'ascending = False'
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang
# ..             ...
# 467       Alcoutim
# 212       Alarobia
# 472          Aketi
# 66          Aizhai
# 581          Abuja
#
# [601 rows x 1 columns]

# %%
cities.sort_values(by = ["City"], ascending = True).head() # Método 'sort_values()' organiza los datos del dataframe 'cities' de acuerdo a la columna 'city, alfabéticamente desde la A hasta la Z por el argumento 'ascending = True', y solo muestra las cinco (5) primeras filas por el método 'head()'
# Out:
#          City
# 581     Abuja
# 66     Aizhai
# 472     Aketi
# 212  Alarobia
# 467  Alcoutim

# %%
cities = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", usecols = ["City"])
cities
cities.sort_values(by = ["City"], ascending = False, inplace = True) # Argumento 'inplace = True' ordena que los cambios en el orden se harán en el mismo dataframe, no en una copia
cities
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang
# ..             ...
# 467       Alcoutim
# 212       Alarobia
# 472          Aketi
# 66          Aizhai
# 581          Abuja
#
# [601 rows x 1 columns]

# %%
cities.sort_index() # Método 'sort_index()' ordena el dataframe 'cities' por el número de fila
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# ..             ...
# 596        Lobitos
# 597         Bremen
# 598         Harare
# 599          Lagos
# 600         Oshawa
#
# [601 rows x 1 columns]

# %%
#cities
pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv")
cities.sort_index(ascending = True, inplace = True) # Método 'sort_index()' ordena el dataframe 'cities' por el número de fila, desde 0 a 600 gracias al argumento 'ascending = True' y aplica los cambios en el mismo dataframe gracias al argumento 'inplace = True'
cities
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# ..             ...
# 596        Lobitos
# 597         Bremen
# 598         Harare
# 599          Lagos
# 600         Oshawa
#
# [601 rows x 1 columns]

# %%
print(cities) # Imprime el dataframe 'cities'
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# ..             ...
# 596        Lobitos
# 597         Bremen
# 598         Harare
# 599          Lagos
# 600         Oshawa
#
# [601 rows x 1 columns]

# %%
import pandas as pd

data = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv") # Crea un dataframe llamado 'data' incluyendo todas sus columnas
data
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
data = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", index_col = ["City"]) # Argumento 'index_col' determina la columna 'city' como el índice del dataframe 'data'
data = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", usecols = ["City"])
data = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv")
data.head()
# Out:
#             City     Country  Population
# 0         Kajuru    Botswana       21722
# 1           Leon       Spain        5629
# 2            Osh  kyrgyzstan        5679
# 3  Shumikhinskiy      Russia       10085
# 4       Bundoran     Ireland       23421

# %%
#data[1] # Instrucción mal digitada, no retorna nada
 # --- ADICIONAL --- #
data.iloc[1] # Instrucción para acceder a una fila en concreto
# Out:
# City           Leon
# Country       Spain
# Population     5629
# Name: 1, dtype: object

# %%
cities = data["City"] # Dataframe 'cities' cuya info es parte de otro dataframe 'data' donde solo se accede a la columna 'cities'
cities.head()
# Out:
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# Name: City, dtype: object

# %%
#cities[19] # Instrucción mal digitada, no retorna nada
cities.iloc[19] # Instrucción correcta
# Out:
# City    Fort Worth
# Name: 19, dtype: object

# %%
cities[10:20] # Instrucción para acceder a cierto intervalo de filas
# Out:
#            City
# 10          Ise
# 11       Volovo
# 12       Caujul
# 13   Kutloanong
# 14     Kobuleti
# 15       Senlis
# 16       Wufeng
# 17       Picton
# 18  Johor Bahru
# 19   Fort Worth

# %%
cities[:15] # Instrucción para acceder desde la fila 0 hasta la fila 'n'
# Out:
# 0            Kajuru
# 1              Leon
# 2               Osh
# 3     Shumikhinskiy
# 4          Bundoran
# 5         La Paloma
# 6             Tutup
# 7           Ondores
# 8           Heredia
# 9              Gaio
# 10              Ise
# 11           Volovo
# 12           Caujul
# 13       Kutloanong
# 14         Kobuleti
# Name: City, dtype: object

# %%
cities[0:26:2] # Instrucción para acceder desde la fila 0 hasta la fila 'n' de dos (2) en dos (2)
# Out:
# 0          Kajuru
# 2             Osh
# 4        Bundoran
# 6           Tutup
# 8         Heredia
# 10            Ise
# 12         Caujul
# 14       Kobuleti
# 16         Wufeng
# 18    Johor Bahru
# 20     Santa Cruz
# 22         Maubin
# 24          Itzer
# Name: City, dtype: object

# %%
cities[-10:] # Instrucción para acceder desde la última fila hasta la fila '-n'
# Out:
# 591    Bagumbayan
# 592      Tuanshan
# 593       Sapporo
# 594    Cocachacra
# 595        Kurjan
# 596       Lobitos
# 597        Bremen
# 598        Harare
# 599         Lagos
# 600        Oshawa
# Name: City, dtype: object

# %%
cities.iloc[[3, 5, 7]] # Método e Instrucción para acceder a ciertas filas en específico
#cities.sort_values()
# Out:
#             City
# 3  Shumikhinskiy
# 5      La Paloma
# 7        Ondores

# %%
#Retrieving data from a series by index label:

#city = pd.read_csv("Cities.csv", usecols = ["City", "Country"])
city = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", usecols = ["City", "Country"], index_col = "City") # Argumentos para acceder solo a las columnas 'city' y 'country', convirtiendo 'city' es el index
city = city["Country"]
city
# Out:
# City
# Kajuru             Botswana
# Leon                  Spain
# Osh              kyrgyzstan
# Shumikhinskiy        Russia
# Bundoran            Ireland
#                     ...
# Lobitos                Peru
# Bremen              Germany
# Harare             Zimbabwe
# Lagos               Nigeria
# Oshawa               Canada
# Name: Country, Length: 601, dtype: object

# %%
city[0] # Instrucción que retorna la info de la fila 'n' de la columna 'city'
# Out:
# <ipython-input-69-8f5a1a4338dc>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city[0]
# 'Botswana'

# %%
city["Lobitos"] # Instrucción que retorna la info de 'lobitos' (en este caso, encontró dos resultados)
# Out:
# City
# Lobitos    Peru
# Lobitos    Peru
# Name: Country, dtype: object

# %%
city["Kajuru"] # Instrucción para retorna la info de 'kajuru' (encontró un solo resultado)
# Out:
# 'Botswana'

# %%
city.sort_index(inplace = True, ascending = True) # Instrucción y argumentos ya explicados
city
# Out:
# City
# Abuja                                     Nigeria
# Aizhai                                      China
# Aketi            Democratic Republic of the Congo
# Alarobia                               Madagascar
# Alcoutim                                 Portugal
#                                ...
# Zhongshangang                               China
# Zhongshangang                               China
# Zhongxing                                   China
# Zhuoshui                                    China
# Zliv                               Czech Republic
# Name: Country, Length: 601, dtype: object

# %%
city["Abuja":"Bremen"] # Instrucción para acceder desde cierto valor de 'city' hasta cierto valor del mismo
# Out:
# City
# Abuja                  Nigeria
# Bantawora            Indonesia
# Waihai                   China
# Zhangcun                 China
# Plaeng Yao            Thailand
# Guja                     Japan
# Caijiagang               China
# Consuelo           Philippines
# Santa Magdalena    Philippines
# Gemblengmulyo        Indonesia
# Bagumbayan         Philippines
# Tuanshan                 China
# Sapporo                  Japan
# Cocachacra                Peru
# Kurjan                 Albania
# Lobitos                   Peru
# Bremen                 Germany
# Name: Country, dtype: object

# %%
city[:"Bremen"] # Instrucción para acceder desde el primer valor de 'city' hasta el valor específicado 'bremen'
# Out:
# City
# Kajuru             Botswana
# Leon                  Spain
# Osh              kyrgyzstan
# Shumikhinskiy        Russia
# Bundoran            Ireland
#                     ...
# Sapporo               Japan
# Cocachacra             Peru
# Kurjan              Albania
# Lobitos                Peru
# Bremen              Germany
# Name: Country, Length: 598, dtype: object

# %%
city[["Bolgar", "Abuja", "Osh"]] # Instrucción para acceder solo a tres filas de 'city'
# Out:
# City
# Bolgar        Russia
# Abuja        Nigeria
# Osh       kyrgyzstan
# Name: Country, dtype: object

# %%
city.head(10) # Método 'head()' para acceder a las n primeras filas (en este caso, 10)
# Out:
# City
# Abuja                                      Nigeria
# Aizhai                                       China
# Aketi             Democratic Republic of the Congo
# Alarobia                                Madagascar
# Alcoutim                                  Portugal
# Alis                                          Peru
# Alvaro Obregon                              Mexico
# Amargosa                                    Brazil
# Amuru                                       Uganda
# Anan                                         Japan
# Name: Country, dtype: object

# %%
city["Abuja": "Anan": 2] # Instrucción para acceder desde 'abuja hasta 'anan' de dos (2) en dos (2)
# Out:
# City
# Abuja                                      Nigeria
# Aketi             Democratic Republic of the Congo
# Alcoutim                                  Portugal
# Alvaro Obregon                              Mexico
# Amuru                                       Uganda
# Name: Country, dtype: object

# %%
data = pd.read_csv("/content/drive/MyDrive/dataAnalisys/Cities.csv", usecols = ["City", "Country"], index_col = "City") # Instrucciones y argumentos ya explicados
data.sort_index(inplace = True)
data
# Out:
#                                         Country
# City
# Abuja                                   Nigeria
# Aizhai                                    China
# Aketi          Democratic Republic of the Congo
# Alarobia                             Madagascar
# Alcoutim                               Portugal
# ...                                         ...
# Zhongshangang                             China
# Zhongshangang                             China
# Zhongxing                                 China
# Zhuoshui                                  China
# Zliv                             Czech Republic
#
# [601 rows x 1 columns]

# %%
city = data["Country"] # Instrucciones y argumentos ya explicados
city
# Out:
# City
# Abuja                                     Nigeria
# Aizhai                                      China
# Aketi            Democratic Republic of the Congo
# Alarobia                               Madagascar
# Alcoutim                                 Portugal
#                                ...
# Zhongshangang                               China
# Zhongshangang                               China
# Zhongxing                                   China
# Zhuoshui                                    China
# Zliv                               Czech Republic
# Name: Country, Length: 601, dtype: object

# %%
city.get(0) # Método 'get()' obtiene el valor correspondiente a la fila 'n' (en este caso, fila 0)
# Out:
# <ipython-input-78-3b8953b357aa>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city.get(0)
# 'Botswana'

# %%
city.get([1, 5]) # Método 'get()' obtiene valores correspondientes de las filas desde 'n' hasta 'n' (en este caso, desde 1 hasta 5)
# Out:
# <ipython-input-81-26f1bf906b27>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city.get([1, 5]) # Método 'get()' obtiene valores correspondientes de las filas desde 'n' hasta 'n' (en este caso, desde 1 hasta 5)
# City
# Leon           Spain
# La Paloma    Uruguay
# Name: Country, dtype: object

# %%
#city.get(["Aizahai", "Alis"])
print(city.get(["Aizahai", "Alis"])) # Imprime los valores de las filas 'aizahai' y 'alis', como no existen, devuelve 'none'
print(city.get(["Leon", "La Paloma"])) # Imprime los valores de las filas 'leon' y 'la paloma', como si existen, devuelve sus valores
# Out:
# None
# City
# Leon           Spain
# La Paloma    Uruguay
# Name: Country, dtype: object

# %%
print(city.get(780)) # Imprime los valores de la fila '780', devuelve 'none' porque no existe dicha fila
# Out:
# None
# <ipython-input-87-bc7c82276ab4>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(city.get(780))

# %%
city.dtype # Método 'dytpe' para acceder al tipo de datos que contiene
# Out:
# dtype('O')

# %%
city.values # Método 'values' para acceder a todos los valores de la columna 'city'
# Out:
# array(['Botswana', 'Spain', 'kyrgyzstan', 'Russia', 'Ireland', 'Uruguay',
#        'Indonesia', 'Peru', 'Costa Rica', 'Portugal', 'Japan', 'Russia',
#        'Peru', 'South Africa', 'Georgia', 'France', 'China',
#        'New Zealand', 'Malaysia', 'United States', 'Philippines',
#        'Philippines', 'Myanmar', 'Nicaragua', 'Morocco', 'China',
#        'Uruguay', 'Russia', 'Cape Verde', 'Venezuela', 'Philippines',
#        'Thailand', 'China', 'Ukraine', 'Madagascar', 'China', 'Indonesia',
#        'Oman', 'Sweden', 'France', 'China', 'Gambia', 'China', 'Peru',
#        'Russia', 'China', 'Russia', 'Peru', 'Dominican Republic',
#        'Philippines', 'China', 'France', 'France', 'Brazil', 'Panama',
#        'Ukraine', 'Indonesia', 'Philippines', 'Indonesia', 'Russia',
#        'Portugal', 'Nigeria', 'Bolivia', 'China', 'Russia', 'Bulgaria',
#        'China', 'Brazil', 'Russia', 'China', 'Bolivia', 'Syria',
#        'Argentina', 'Ireland', 'Russia', 'Senegal', 'Indonesia',
# ...

# %%
population = pop
population
# Out:
#      Population
# 0         21722
# 1          5629
# 2          5679
# 3         10085
# 4         23421
# ..          ...
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000
#
# [601 rows x 1 columns]

# %%
population = pop["Population"]
population
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
population.dtype # Método ya explicado
# Out:
# dtype('int64')

# %%
#pop.values
population.values # Método 'values' para acceder a todos los valores de 'population'
# Out:
# array([21722,  5629,  5679, 10085, 23421, 22154, 11558, 13288,  5835,
#         9942, 18354,  8184,  4672, 10733, 16577, 13265, 38745, 10120,
#        16567, 24397, 15170,  5589, 17693,  2545, 21997, 11174, 21758,
#         5860, 13204, 24943,  7476, 18560, 16422, 20559,  8519, 24805,
#        20119,  5283, 19947, 16254,  9746,  4187,  3515, 22829,  4431,
#        11071,  5972, 23638,  5217, 19156, 24196,  3106,  5428, 20167,
#        15519, 24424, 20539, 13138, 11393, 22345, 19021, 22267, 23801,
#        19485,  2653,  8634, 10173,  2528,  7332, 18425, 16527,  3103,
#        22667,  6901,  5532, 24272, 20178, 14050, 22908, 22016, 10667,
#        12517, 21987,  3900, 16041,  3507,  4002, 13997, 21675, 13299,
#        11913, 24383, 14784, 14841,  2863, 16916, 13234,  5349, 22436,
#        12620, 10021, 20120, 20168, 21621,  3695, 24722, 18096, 15913,
#        19734, 17535, 13034,  4291, 18899, 21153, 12967, 17231, 23458,
# ...

# %%
city.index # Método 'index' devuelve el índice de 'city'
# Out:
# Index(['Abuja', 'Aizhai', 'Aketi', 'Alarobia', 'Alcoutim', 'Alis',
#        'Alvaro Obregon', 'Amargosa', 'Amuru', 'Anan',
#        ...
#        'Zhangcun', 'Zhangzhu', 'Zhatay', 'Zhentou', 'Zhiletovo',
#        'Zhongshangang', 'Zhongshangang', 'Zhongxing', 'Zhuoshui', 'Zliv'],
#       dtype='object', name='City', length=601)

# %%
population.index # Método 'index' devuelve el índice de 'population'
# Out:
# RangeIndex(start=0, stop=601, step=1)

# %%
city.is_unique # Método 'is_unique' devuelve un valor booleano si los valores de 'city' son únicos
# Out:
# False

# %%
population.is_unique # Método 'is_unique' devuelve un valor booleano si los valores de 'population' son únicos
# Out:
# False

# %%
city.ndim # Método 'ndim' devuelve el número/cantidad de dimenisones de la estructura de datos
# Out:
# 1

# %%
#pop.ndim
population.ndim # Método 'ndim' devuelve el número/cantidad de dimenisones de la estructura de datos
# Out:
# 1
